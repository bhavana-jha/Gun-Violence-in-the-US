# %% [markdown]
# # This Script contains:
# 1. Import of Libraries and Data set
# 2. Data Consistency Check
# 3. Data Cleaning
# 4. Export of Clean data

# %% [markdown]
# # 1. Import of Libraries and Data set

# %%
#Importing libraries
import pandas as pd
import numpy as np
import os

# %%
#Import Dataset
df=pd.read_csv(r'/Users/navneetjha/Desktop/Career foundry Docs/exercises/Data Immersion /Achievement 6/Dataset/gun-violence-data_01-2013_03-2018.csv',index_col=False)

# %%
# Checking head rows of the data set
df.head(50)
# Out:
#     incident_id        date                 state        city_or_county  \
# 0        461105  2013-01-01          Pennsylvania            Mckeesport
# 1        460726  2013-01-01            California             Hawthorne
# 2        478855  2013-01-01                  Ohio                Lorain
# 3        478925  2013-01-05              Colorado                Aurora
# 4        478959  2013-01-07        North Carolina            Greensboro
# 5        478948  2013-01-07              Oklahoma                 Tulsa
# 6        479363  2013-01-19            New Mexico           Albuquerque
# 7        479374  2013-01-21             Louisiana           New Orleans
# 8        479389  2013-01-21            California             Brentwood
# 9        492151  2013-01-23              Maryland             Baltimore
# 10       491674  2013-01-23             Tennessee           Chattanooga
# 11       479413  2013-01-25              Missouri           Saint Louis
# ...

# %% [markdown]
# # 2. Data Consistency Check

# %%
# Checking shape of the data set
df.shape
# Out:
# (239677, 29)

# %% [markdown]
# ###### There are 239677 rows and 29 columns in the raw data set

# %%
# Checking data info
df.info
# Out:
# <bound method DataFrame.info of         incident_id        date           state city_or_county  \
# 0            461105  2013-01-01    Pennsylvania     Mckeesport
# 1            460726  2013-01-01      California      Hawthorne
# 2            478855  2013-01-01            Ohio         Lorain
# 3            478925  2013-01-05        Colorado         Aurora
# 4            478959  2013-01-07  North Carolina     Greensboro
# ...             ...         ...             ...            ...
# 239672      1083142  2018-03-31       Louisiana          Rayne
# 239673      1083139  2018-03-31       Louisiana   Natchitoches
# 239674      1083151  2018-03-31       Louisiana         Gretna
# 239675      1082514  2018-03-31           Texas        Houston
# 239676      1081940  2018-03-31           Maine   Norridgewock
#
#                                           address  n_killed  n_injured  \
# 0       1506 Versailles Avenue and Coursin Street         0          4
# ...

# %%
# Checking data description
df.describe()
# Out:
#         incident_id       n_killed      n_injured  congressional_district  \
# count  2.396770e+05  239677.000000  239677.000000           227733.000000
# mean   5.593343e+05       0.252290       0.494007                8.001265
# std    2.931287e+05       0.521779       0.729952                8.480835
# min    9.211400e+04       0.000000       0.000000                0.000000
# 25%    3.085450e+05       0.000000       0.000000                2.000000
# 50%    5.435870e+05       0.000000       0.000000                5.000000
# 75%    8.172280e+05       0.000000       1.000000               10.000000
# max    1.083472e+06      50.000000      53.000000               53.000000
#
#             latitude      longitude  n_guns_involved  state_house_district  \
# count  231754.000000  231754.000000    140226.000000         200905.000000
# mean       37.546598     -89.338348         1.372442             55.447132
# std         5.130763      14.359546         4.678202             42.048117
# ...

# %%
# Checking basis stats
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   incident_id                  239677 non-null  int64
#  1   date                         239677 non-null  object
#  2   state                        239677 non-null  object
#  3   city_or_county               239677 non-null  object
#  4   address                      223180 non-null  object
#  5   n_killed                     239677 non-null  int64
#  6   n_injured                    239677 non-null  int64
#  7   incident_url                 239677 non-null  object
#  8   source_url                   239209 non-null  object
#  9   incident_url_fields_missing  239677 non-null  bool
#  10  congressional_district       227733 non-null  float64
#  11  gun_stolen                   140179 non-null  object
# ...

# %% [markdown]
# Multiple columns have missing values

# %%
# Checking data columns
df.columns
# Out:
# Index(['incident_id', 'date', 'state', 'city_or_county', 'address', 'n_killed',
#        'n_injured', 'incident_url', 'source_url',
#        'incident_url_fields_missing', 'congressional_district', 'gun_stolen',
#        'gun_type', 'incident_characteristics', 'latitude',
#        'location_description', 'longitude', 'n_guns_involved', 'notes',
#        'participant_age', 'participant_age_group', 'participant_gender',
#        'participant_name', 'participant_relationship', 'participant_status',
#        'participant_type', 'sources', 'state_house_district',
#        'state_senate_district'],
#       dtype='object')

# %%
# Extracting relevant columns
df_2=df[['incident_id','date','state','city_or_county','address', 'n_killed', 'n_injured','congressional_district', 'gun_stolen','gun_type',
         'incident_characteristics', 'latitude','location_description', 'longitude', 'n_guns_involved','participant_age', 'participant_age_group', 'participant_gender','participant_relationship', 'participant_status',
         'participant_type','state_house_district', 'state_senate_district']]

# %%
#Printing head rows of df_2
df_2.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#    congressional_district              gun_stolen                gun_type  \
# 0                    14.0                     NaN                     NaN
# ...

# %% [markdown]
# # 3. Data Cleaning

# %%
#Checking for duplicate data 
df_2[df_2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [incident_id, date, state, city_or_county, address, n_killed, n_injured, congressional_district, gun_stolen, gun_type, incident_characteristics, latitude, location_description, longitude, n_guns_involved, participant_age, participant_age_group, participant_gender, participant_relationship, participant_status, participant_type, state_house_district, state_senate_district]
# Index: []
#
# [0 rows x 23 columns]

# %%
# Checking for missing values
df_missing_values=df_2.isnull().sum()

# %%
# Printing missing values
df_missing_values
# Out:
# incident_id                      0
# date                             0
# state                            0
# city_or_county                   0
# address                      16497
# n_killed                         0
# n_injured                        0
# congressional_district       11944
# gun_stolen                   99498
# gun_type                     99451
# incident_characteristics       326
# latitude                      7923
# location_description        197588
# longitude                     7923
# n_guns_involved              99451
# participant_age              92298
# participant_age_group        42119
# participant_gender           36362
# participant_relationship    223903
# participant_status           27626
# participant_type             24863
# state_house_district         38772
# state_senate_district        32335
# dtype: int64

# %%
# Checking percentage of missing value
df_missing_value_percentage=df_2.isnull().mean()*100

# %%
#Printing missing value percentage
df_missing_value_percentage
# Out:
# incident_id                  0.000000
# date                         0.000000
# state                        0.000000
# city_or_county               0.000000
# address                      6.883013
# n_killed                     0.000000
# n_injured                    0.000000
# congressional_district       4.983373
# gun_stolen                  41.513370
# gun_type                    41.493760
# incident_characteristics     0.136016
# latitude                     3.305699
# location_description        82.439283
# longitude                    3.305699
# n_guns_involved             41.493760
# participant_age             38.509327
# participant_age_group       17.573234
# participant_gender          15.171251
# participant_relationship    93.418643
# participant_status          11.526346
# participant_type            10.373544
# state_house_district        16.176771
# state_senate_district       13.491073
# dtype: float64

# %% [markdown]
# Except six columns all other columns contain missing values.

# %%
#Dropping columns that have more than 80% missing values
df_3= df_2[['incident_id','date','state','city_or_county','address', 'n_killed', 'n_injured','congressional_district', 'gun_stolen','gun_type',
         'incident_characteristics', 'latitude','longitude', 'n_guns_involved','participant_age', 'participant_age_group', 'participant_gender', 'participant_status',
         'participant_type','state_house_district', 'state_senate_district']]

# %%
# Dropping missing values
df_cleaned=df_3.dropna()

# %%
#Printing cleaned dataset
df_cleaned.head()
# Out:
#     incident_id        date           state city_or_county  \
# 2        478855  2013-01-01            Ohio         Lorain
# 4        478959  2013-01-07  North Carolina     Greensboro
# 6        479363  2013-01-19      New Mexico    Albuquerque
# 10       491674  2013-01-23       Tennessee    Chattanooga
# 11       479413  2013-01-25        Missouri    Saint Louis
#
#                                 address  n_killed  n_injured  \
# 2                 1776 East 28th Street         1          3
# 4             307 Mourning Dove Terrace         2          2
# 6                        2806 Long Lane         5          0
# 10                       1501 Dodds Ave         1          3
# 11  W Florissant Ave and Riverview Blvd         1          3
#
#     congressional_district              gun_stolen  \
# 2                      9.0  0::Unknown||1::Unknown
# 4                      6.0  0::Unknown||1::Unknown
# 6                      1.0  0::Unknown||1::Unknown
# ...

# %%
# Checking shape of cleaned data set
df_cleaned.shape
# Out:
# (67116, 21)

# %%
df_cleaned.value_counts().sum()
# Out:
# 67116

# %%
#Checking for missing values in cleaned set
df_cleaned.isnull().sum()
# Out:
# incident_id                 0
# date                        0
# state                       0
# city_or_county              0
# address                     0
# n_killed                    0
# n_injured                   0
# congressional_district      0
# gun_stolen                  0
# gun_type                    0
# incident_characteristics    0
# latitude                    0
# longitude                   0
# n_guns_involved             0
# participant_age             0
# participant_age_group       0
# participant_gender          0
# participant_status          0
# participant_type            0
# state_house_district        0
# state_senate_district       0
# dtype: int64

# %%
# Checking basic info about cleaned data
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67116 entries, 2 to 239676
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   incident_id               67116 non-null  int64
#  1   date                      67116 non-null  object
#  2   state                     67116 non-null  object
#  3   city_or_county            67116 non-null  object
#  4   address                   67116 non-null  object
#  5   n_killed                  67116 non-null  int64
#  6   n_injured                 67116 non-null  int64
#  7   congressional_district    67116 non-null  float64
#  8   gun_stolen                67116 non-null  object
#  9   gun_type                  67116 non-null  object
#  10  incident_characteristics  67116 non-null  object
#  11  latitude                  67116 non-null  float64
#  12  longitude                 67116 non-null  float64
# ...

# %%
# Checking basis description of cleaned data
df_cleaned.describe()
# Out:
#         incident_id      n_killed     n_injured  congressional_district  \
# count  6.711600e+04  67116.000000  67116.000000            67116.000000
# mean   7.220504e+05      0.367081      0.503084                8.030052
# std    2.427656e+05      0.638799      0.784947                8.217204
# min    9.213500e+04      0.000000      0.000000                0.000000
# 25%    5.463350e+05      0.000000      0.000000                2.000000
# 50%    7.655990e+05      0.000000      0.000000                5.000000
# 75%    9.161165e+05      1.000000      1.000000               11.000000
# max    1.083435e+06     50.000000     53.000000               53.000000
#
#            latitude     longitude  n_guns_involved  state_house_district  \
# count  67116.000000  67116.000000     67116.000000          67116.000000
# mean      37.765321    -89.700344         1.292196             53.334019
# std        4.847671     14.119407         3.328392             43.727232
# ...

# %% [markdown]
# It looks like the column n_guns_involved contains an outlier.

# %%
#Checking for duplicate data in cleaned data set
df_cleaned[df_cleaned.duplicated()]
# Out:
# Empty DataFrame
# Columns: [incident_id, date, state, city_or_county, address, n_killed, n_injured, congressional_district, gun_stolen, gun_type, incident_characteristics, latitude, longitude, n_guns_involved, participant_age, participant_age_group, participant_gender, participant_status, participant_type, state_house_district, state_senate_district]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Exporting cleaned data set 
df_cleaned.to_csv('gun_violence_cleaned',index=False)
